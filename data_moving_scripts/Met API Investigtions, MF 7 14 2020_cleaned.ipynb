# %% [markdown]
# # Met API Investigations
#
# In this notebook, I investigated how we could use the table describing the individual images, and pull together images from the relevant cultures.
#
# ### Table of contents
#
# 1. Analysis of API
# 2. Bigquery dataset
# 3. Reviewing Download Speeds
# 4. Defining What to run in gsutil
#
# ## 1. Analysis of API

# %% [markdown]
# At first, it does seem that we could try to use their API - here I investigated connecting to it.

# %%
import requests

response = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/objects')

# %%
response.json()['total']
# Out:
# 474434

# %%
# %timeit  IDs = response.json()['objectIDs'][1:300]
# Out:
# 108 ms ± 3.72 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
for i in IDs[30:72]:
    url = 'https://collectionapi.metmuseum.org/public/collection/v1/objects/' + str(i)
    print(url)
    item = requests.get(url)
# Out:
# https://collectionapi.metmuseum.org/public/collection/v1/objects/32
# https://collectionapi.metmuseum.org/public/collection/v1/objects/33
# https://collectionapi.metmuseum.org/public/collection/v1/objects/34
# https://collectionapi.metmuseum.org/public/collection/v1/objects/35
# https://collectionapi.metmuseum.org/public/collection/v1/objects/36
# https://collectionapi.metmuseum.org/public/collection/v1/objects/37
# https://collectionapi.metmuseum.org/public/collection/v1/objects/38
# https://collectionapi.metmuseum.org/public/collection/v1/objects/39
# https://collectionapi.metmuseum.org/public/collection/v1/objects/40
# https://collectionapi.metmuseum.org/public/collection/v1/objects/41
# https://collectionapi.metmuseum.org/public/collection/v1/objects/42
# https://collectionapi.metmuseum.org/public/collection/v1/objects/43
# https://collectionapi.metmuseum.org/public/collection/v1/objects/44
# https://collectionapi.metmuseum.org/public/collection/v1/objects/45
# https://collectionapi.metmuseum.org/public/collection/v1/objects/46
# https://collectionapi.metmuseum.org/public/collection/v1/objects/47
# https://collectionapi.metmuseum.org/public/collection/v1/objects/48
# https://collectionapi.metmuseum.org/public/collection/v1/objects/49
# https://collectionapi.metmuseum.org/public/collection/v1/objects/50
# https://collectionapi.metmuseum.org/public/collection/v1/objects/51
# https://collectionapi.metmuseum.org/public/collection/v1/objects/52
# https://collectionapi.metmuseum.org/public/collection/v1/objects/53
# https://collectionapi.metmuseum.org/public/collection/v1/objects/56
# https://collectionapi.metmuseum.org/public/collection/v1/objects/57
# https://collectionapi.metmuseum.org/public/collection/v1/objects/58
# https://collectionapi.metmuseum.org/public/collection/v1/objects/59
# https://collectionapi.metmuseum.org/public/collection/v1/objects/62
# https://collectionapi.metmuseum.org/public/collection/v1/objects/63
# https://collectionapi.metmuseum.org/public/collection/v1/objects/64
# https://collectionapi.metmuseum.org/public/collection/v1/objects/65
# https://collectionapi.metmuseum.org/public/collection/v1/objects/68
# https://collectionapi.metmuseum.org/public/collection/v1/objects/69
# https://collectionapi.metmuseum.org/public/collection/v1/objects/70
# https://collectionapi.metmuseum.org/public/collection/v1/objects/71
# https://collectionapi.metmuseum.org/public/collection/v1/objects/72
# https://collectionapi.metmuseum.org/public/collection/v1/objects/73
# https://collectionapi.metmuseum.org/public/collection/v1/objects/74
# https://collectionapi.metmuseum.org/public/collection/v1/objects/75
# https://collectionapi.metmuseum.org/public/collection/v1/objects/76
# https://collectionapi.metmuseum.org/public/collection/v1/objects/77
# https://collectionapi.metmuseum.org/public/collection/v1/objects/78
# https://collectionapi.metmuseum.org/public/collection/v1/objects/79

# %%
item.json()
# Out:
# {'objectID': 79,
#  'isHighlight': False,
#  'accessionNumber': '37.174.2',
#  'accessionYear': '1937',
#  'isPublicDomain': True,
#  'primaryImage': 'https://images.metmuseum.org/CRDImages/ad/original/113560.jpg',
#  'primaryImageSmall': 'https://images.metmuseum.org/CRDImages/ad/web-large/113560.jpg',
#  'additionalImages': [],
#  'constituents': None,
#  'department': 'The American Wing',
#  'objectName': 'Andiron',
#  'title': 'Andiron',
#  'culture': '',
#  'period': '',
#  'dynasty': '',
#  'reign': '',
#  'portfolio': '',
#  'artistRole': '',
#  'artistPrefix': '',
#  'artistDisplayName': '',
#  'artistDisplayBio': '',
#  'artistSuffix': '',
#  'artistAlphaSort': '',
#  'artistNationality': '',
#  'artistBeginDate': '',
#  'artistEndDate': '',
#  'artistGender': '',
#  'artistWikidata_URL': '',
#  'artistULAN_URL': '',
#  'objectDate': 'ca. 1700',
#  'objectBeginDate': 1697,
#  'objectEndDate': 1700,
#  'medium': 'Brass, iron',
#  'dimensions': '17 3/4 x 24 in. (45.1 x 61 cm)',
#  'creditLine': 'Rogers Fund, 1937',
#  'geographyType': 'Made in',
#  'city': '',
#  'state': '',
#  'county': '',
#  'country': 'Spain',
#  'region': '',
#  'subregion': '',
#  'locale': '',
#  'locus': '',
#  'excavation': '',
#  'river': '',
#  'classification': 'Metal',
#  'rightsAndReproduction': '',
#  'linkResource': '',
#  'metadataDate': '2020-03-02T21:50:01.377Z',
#  'repository': 'Metropolitan Museum of Art, New York, NY',
#  'objectURL': 'https://www.metmuseum.org/art/collection/search/79',
#  'tags': None,
#  'objectWikidata_URL': '',
#  'isTimelineWork': False}

# %%
item.json()['primaryImage']
# Out:
# 'https://images.metmuseum.org/CRDImages/ad/original/113560.jpg'

# %%
import urllib

urllib.request.urlretrieve(item.json()['primaryImage'], "00000001.jpg")
# Out:
# ('00000001.jpg', <http.client.HTTPMessage at 0x2531a62e320>)

# %% [markdown]
# Okay.  So, we can connect, pull a table that creates info, filter out those with no image or other data, and then we can  pull the images.  How long does that take:

# %%
# %timeit urllib.request.urlretrieve(item.json()['primaryImage'], "00000001.jpg")
# Out:
# 455 ms ± 43 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Based on this speed, let's calculate how many hours this would take.

# %%
100000/2/60/60
# Out:
# 13.88888888888889

# %% [markdown]
# Thirteen hours, we may need to use GCP for that part already.

# %% [markdown]
# ## 2. BigQuery Dataset
#
# Below, loading the extension to use bigquery.

# %%
# %load_ext google.cloud.bigquery

# %% [markdown]
# In order to run this, downloaded an auth key per this link:
# https://cloud.google.com/docs/authentication/getting-started#windows
#
#
# then ran this in powershell
# <code>$env:GOOGLE_APPLICATION_CREDENTIALS="C:\Users\matfl\Documents\MSCA 31009 Project -_NUMBER_.json"
#
# set GOOGLE_APPLICATION_CREDENTIALS="C:\Users\matfl\Documents\MSCA 31009 Project -_NUMBER_.json"</code>

# %% [markdown]
# Trying another way...

# %%
import os

credential_path = r"C:\Users\matfl\Documents\MSCA 31009 Project - (details).json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credential_path
from google.cloud import bigquery

# %% [markdown]
# This works - I can now query bq in jupyter.

# %%
# %%bigquery
# SELECT * FROM `bigquery-public-data.the_met.objects` limit 50
# Out:
#          object_number  is_highlight  is_public_domain  object_id  \
# 0       U565 .S68 1740          True              True     681274
# 1     M2149.5 .C5 1768          True              True     681259
# 2     GB1321 .M68 1766          True              True     682011
# 3            272.4 Au8          True              True     591859
# 4        201.9Av3 Av32          True              True     591857
# 5             1984.489         False              True      38568
# 6             1998.348         False              True      41900
# 7             91.1.926         False              True      60517
# 8             91.1.927         False              True      60518
# 9           1980.528.1         False              True      38565
# 10          1985.398.2         False              True      38569
# 11          1987.407.7         False              True      38564
# 12          1987.420.4         False              True      38553
# 13          1991.409.7         False              True      44649
# 14          1991.409.8         False              True      44650
# 15          1991.409.9         False              True      44651
# 16         1987.424.21         False              True      38567
# 17         1991.409.10         False              True      44652
# 18         1991.409.11         False              True      44653
# 19         1991.409.12         False              True      44654
# 20         1991.409.13         False              True      44655
# 21         1991.409.14         False              True      44656
# 22         1991.409.15         False              True      44657
# 23         1991.409.16         False              True      44658
# 24         1991.409.19         False              True      44661
# 25         1991.409.20         False              True      44662
# 26         1991.409.21         False              True      44663
# 27         1991.409.22         False              True      44664
# 28         1991.409.23         False              True      44665
# 29         1991.423.10         False              True      38540
# 30        1987.142.371         False              True      37448
# 31        1987.142.372         False              True      38644
# 32        1987.142.373         False              True      38711
# 33        2002.201.204         False              True      63051
# 34        2002.201.205         False              True      63052
# 35     1987.424.20a, b         False              True      38566
# 36  1987.420.5.1–.1210         False              True      38437
# 37               20.83         False              True      60502
# 38            62.97.26         False              True      41964
# 39           25.215.68         False              True      68451
# 40           25.215.69         False              True      68452
# 41           25.215.70         False              True      68453
# 42           25.215.71         False              True      68454
# 43           25.215.72         False              True      68455
# 44           25.215.73         False              True      68456
# 45           25.215.74         False              True      68457
# 46           25.215.75         False              True      70933
# 47           25.215.76         False              True      68458
# 48           25.215.77         False              True      68459
# 49           25.215.78         False              True      68460
#
#        department      object_name  \
# 0   The Libraries             None
# 1   The Libraries             None
# 2   The Libraries             None
# 3   The Libraries             None
# 4   The Libraries             None
# 5       Asian Art           Plaque
# 6       Asian Art           Plaque
# 7       Asian Art        Pipe case
# 8       Asian Art        Pipe case
# 9       Asian Art           Plaque
# 10      Asian Art           Plaque
# 11      Asian Art           Plaque
# 12      Asian Art     Knife handle
# 13      Asian Art           Plaque
# 14      Asian Art   Ritual carving
# 15      Asian Art   Ritual carving
# 16      Asian Art           Plaque
# 17      Asian Art   Ritual carving
# 18      Asian Art   Ritual carving
# 19      Asian Art   Ritual carving
# 20      Asian Art   Ritual carving
# 21      Asian Art   Ritual carving
# 22      Asian Art   Ritual carving
# 23      Asian Art   Ritual carving
# 24      Asian Art   Ritual carving
# 25      Asian Art   Ritual carving
# 26      Asian Art   Ritual carving
# 27      Asian Art   Ritual carving
# 28      Asian Art   Ritual carving
# 29      Asian Art           Figure
# 30      Asian Art           Plaque
# 31      Asian Art           Plaque
# 32      Asian Art           Plaque
# 33      Asian Art           Finial
# 34      Asian Art           Finial
# 35      Asian Art          Plaques
# 36      Asian Art  Beads and bells
# 37      Asian Art              Fan
# 38      Asian Art              Fan
# 39      Asian Art              Fan
# 40      Asian Art              Fan
# 41      Asian Art              Fan
# 42      Asian Art              Fan
# 43      Asian Art              Fan
# 44      Asian Art              Fan
# 45      Asian Art              Fan
# 46      Asian Art              Fan
# 47      Asian Art              Fan
# 48      Asian Art              Fan
# 49      Asian Art              Fan
#
#                                                 title  \
# 0   Proposition concernant le payement et la polic...
# 1                               Loffice de Noël, 1768
# 2         Dialogo sobre hua nova obra no Rio Tejo ...
# 3   Autographs and Sketches from Artist Friends to...
# 4                       S. P. Avery, Engraver on Wood
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
#
#                                              culture period dynasty  ...  \
# 0                                               None   None    None  ...
# 1                                               None   None    None  ...
# 2                                               None   None    None  ...
# 3                                               None   None    None  ...
# 4                           New York: [s.n.], [18--]   None    None  ...
# 5                                              Tibet   None    None  ...
# 6   Afghanistan, possibly of West Indian manufacture   None    None  ...
# 7                                              Japan   None    None  ...
# 8                                              Japan   None    None  ...
# 9                                   Tibet (or Nepal)   None    None  ...
# 10                                             Tibet   None    None  ...
# 11                                             Tibet   None    None  ...
# 12                                             Burma   None    None  ...
# 13                                             Tibet   None    None  ...
# 14                                             Tibet   None    None  ...
# 15                                             Tibet   None    None  ...
# 16                                             Tibet   None    None  ...
# 17                                             Tibet   None    None  ...
# 18                                             Tibet   None    None  ...
# 19                                             Tibet   None    None  ...
# 20                                             Tibet   None    None  ...
# 21                                             Tibet   None    None  ...
# 22                                             Tibet   None    None  ...
# 23                                             Tibet   None    None  ...
# 24                                             Tibet   None    None  ...
# 25                                             Tibet   None    None  ...
# 26                                             Tibet   None    None  ...
# 27                                             Tibet   None    None  ...
# 28                                             Tibet   None    None  ...
# 29                                             Tibet   None    None  ...
# 30                                             Nepal   None    None  ...
# 31                                             Nepal   None    None  ...
# 32                                             Nepal   None    None  ...
# 33                                   Northwest China   None    None  ...
# 34                                   Northwest China   None    None  ...
# 35                                             Tibet   None    None  ...
# 36                                             Tibet   None    None  ...
# 37                                             Japan   None    None  ...
# 38                                             China   None    None  ...
# 39                                             Japan   None    None  ...
# 40                                             Japan   None    None  ...
# 41                                             Japan   None    None  ...
# 42                                             Japan   None    None  ...
# 43                                             Japan   None    None  ...
# 44                                             Japan   None    None  ...
# 45                                             Japan   None    None  ...
# 46                                             Japan   None    None  ...
# 47                                             Japan   None    None  ...
# 48                                             Japan   None    None  ...
# 49                                             Japan   None    None  ...
#
#    subregion locale locus excavation river classification  \
# 0       None   None  None       None  None             ||
# 1       None   None  None       None  None             ||
# 2       None   None  None       None  None             ||
# 3       None   None  None       None  None             ||
# 4       None   None  None       None  None             ||
# 5       None   None  None       None  None           Bone
# 6       None   None  None       None  None           Bone
# 7       None   None  None       None  None           Bone
# 8       None   None  None       None  None           Bone
# 9       None   None  None       None  None           Bone
# 10      None   None  None       None  None           Bone
# 11      None   None  None       None  None           Bone
# 12      None   None  None       None  None           Bone
# 13      None   None  None       None  None           Bone
# 14      None   None  None       None  None           Bone
# 15      None   None  None       None  None           Bone
# 16      None   None  None       None  None           Bone
# 17      None   None  None       None  None           Bone
# 18      None   None  None       None  None           Bone
# 19      None   None  None       None  None           Bone
# 20      None   None  None       None  None           Bone
# 21      None   None  None       None  None           Bone
# 22      None   None  None       None  None           Bone
# 23      None   None  None       None  None           Bone
# 24      None   None  None       None  None           Bone
# 25      None   None  None       None  None           Bone
# 26      None   None  None       None  None           Bone
# 27      None   None  None       None  None           Bone
# 28      None   None  None       None  None           Bone
# 29      None   None  None       None  None           Bone
# 30      None   None  None       None  None           Bone
# 31      None   None  None       None  None           Bone
# 32      None   None  None       None  None           Bone
# 33      None   None  None       None  None           Bone
# 34      None   None  None       None  None           Bone
# 35      None   None  None       None  None           Bone
# 36      None   None  None       None  None           Bone
# 37      None   None  None       None  None           Fans
# 38      None   None  None       None  None           Fans
# 39      None   None  None       None  None           Fans
# 40      None   None  None       None  None           Fans
# 41      None   None  None       None  None           Fans
# 42      None   None  None       None  None           Fans
# 43      None   None  None       None  None           Fans
# 44      None   None  None       None  None           Fans
# 45      None   None  None       None  None           Fans
# 46      None   None  None       None  None           Fans
# 47      None   None  None       None  None           Fans
# 48      None   None  None       None  None           Fans
# 49      None   None  None       None  None           Fans
#
#    rights_and_reproduction                                      link_resource  \
# 0                     None  http://www.metmuseum.org/art/collection/search...
# 1                     None  http://www.metmuseum.org/art/collection/search...
# 2                     None  http://www.metmuseum.org/art/collection/search...
# 3                     None  http://www.metmuseum.org/art/collection/search...
# 4                     None  http://www.metmuseum.org/art/collection/search...
# 5                     None  http://www.metmuseum.org/art/collection/search...
# 6                     None  http://www.metmuseum.org/art/collection/search...
# 7                     None  http://www.metmuseum.org/art/collection/search...
# 8                     None  http://www.metmuseum.org/art/collection/search...
# 9                     None  http://www.metmuseum.org/art/collection/search...
# 10                    None  http://www.metmuseum.org/art/collection/search...
# 11                    None  http://www.metmuseum.org/art/collection/search...
# 12                    None  http://www.metmuseum.org/art/collection/search...
# 13                    None  http://www.metmuseum.org/art/collection/search...
# 14                    None  http://www.metmuseum.org/art/collection/search...
# 15                    None  http://www.metmuseum.org/art/collection/search...
# 16                    None  http://www.metmuseum.org/art/collection/search...
# 17                    None  http://www.metmuseum.org/art/collection/search...
# 18                    None  http://www.metmuseum.org/art/collection/search...
# 19                    None  http://www.metmuseum.org/art/collection/search...
# 20                    None  http://www.metmuseum.org/art/collection/search...
# 21                    None  http://www.metmuseum.org/art/collection/search...
# 22                    None  http://www.metmuseum.org/art/collection/search...
# 23                    None  http://www.metmuseum.org/art/collection/search...
# 24                    None  http://www.metmuseum.org/art/collection/search...
# 25                    None  http://www.metmuseum.org/art/collection/search...
# 26                    None  http://www.metmuseum.org/art/collection/search...
# 27                    None  http://www.metmuseum.org/art/collection/search...
# 28                    None  http://www.metmuseum.org/art/collection/search...
# 29                    None  http://www.metmuseum.org/art/collection/search...
# 30                    None  http://www.metmuseum.org/art/collection/search...
# 31                    None  http://www.metmuseum.org/art/collection/search...
# 32                    None  http://www.metmuseum.org/art/collection/search...
# 33                    None  http://www.metmuseum.org/art/collection/search...
# 34                    None  http://www.metmuseum.org/art/collection/search...
# 35                    None  http://www.metmuseum.org/art/collection/search...
# 36                    None  http://www.metmuseum.org/art/collection/search...
# 37                    None  http://www.metmuseum.org/art/collection/search...
# 38                    None  http://www.metmuseum.org/art/collection/search...
# 39                    None  http://www.metmuseum.org/art/collection/search...
# 40                    None  http://www.metmuseum.org/art/collection/search...
# 41                    None  http://www.metmuseum.org/art/collection/search...
# 42                    None  http://www.metmuseum.org/art/collection/search...
# 43                    None  http://www.metmuseum.org/art/collection/search...
# 44                    None  http://www.metmuseum.org/art/collection/search...
# 45                    None  http://www.metmuseum.org/art/collection/search...
# 46                    None  http://www.metmuseum.org/art/collection/search...
# 47                    None  http://www.metmuseum.org/art/collection/search...
# 48                    None  http://www.metmuseum.org/art/collection/search...
# 49                    None  http://www.metmuseum.org/art/collection/search...
#
#                metadata_date                                repository
# 0  2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 1  2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 2  2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 3  2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 4  2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 5  2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 6  2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 7  2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 8  2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 9  2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 10 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 11 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 12 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 13 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 14 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 15 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 16 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 17 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 18 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 19 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 20 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 21 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 22 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 23 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 24 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 25 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 26 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 27 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 28 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 29 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 30 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 31 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 32 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 33 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 34 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 35 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 36 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 37 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 38 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 39 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 40 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 41 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 42 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 43 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 44 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 45 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 46 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 47 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 48 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
# 49 2017-02-06 08:00:16+00:00  Metropolitan Museum of Art, New York, NY
#
# [50 rows x 43 columns]

# %% [markdown]
# Let's see how they're spread across departments - at this point, we still hadn't yet decided which variable we planned to predict.  This distribution isn't great, so we'll look at another.

# %%
# %%bigquery
# SELECT department, count(*) FROM `bigquery-public-data.the_met.objects` GROUP BY department
# Out:
#                                    department    f0_
# 0                               The Libraries    120
# 1                                   Asian Art  29844
# 2                                 Islamic Art  10435
# 3                                 Photographs   6583
# 4                                Medieval Art   6838
# 5                               The Cloisters   2268
# 6                              Arms and Armor   4252
# 7                          European Paintings   2322
# 8                         Drawings and Prints  43488
# 9                         Greek and Roman Art  12518
# 10                        Musical Instruments   1251
# 11                   American Decorative Arts   8942
# 12                   Ancient Near Eastern Art   6173
# 13                   Robert Lehman Collection   2411
# 14                Modern and Contemporary Art   1112
# 15           American Paintings and Sculpture   4783
# 16     European Sculpture and Decorative Arts  30611
# 17  Arts of Africa, Oceania, and the Americas   6021
# 18                               Egyptian Art  12278
# 19                          Costume Institute   7824

# %%
# %%bigquery
# SELECT a.department, count(DISTINCT b.gcs_url)
# FROM `bigquery-public-data.the_met.objects` a JOIN `bigquery-public-data.the_met.images` b
# on a.object_id = b.object_id GROUP BY a.department ORDER BY 2 desc
# Out:
#                                    department    f0_
# 0                                   Asian Art  74039
# 1                         Drawings and Prints  60452
# 2      European Sculpture and Decorative Arts  57371
# 3                                 Islamic Art  36275
# 4                                Egyptian Art  24783
# 5                           Costume Institute  22257
# 6                                Medieval Art  19615
# 7                         Greek and Roman Art  18389
# 8                    American Decorative Arts  18201
# 9                                 Photographs  13668
# 10                             Arms and Armor  11645
# 11  Arts of Africa, Oceania, and the Americas   9652
# 12           American Paintings and Sculpture   9182
# 13                   Ancient Near Eastern Art   6506
# 14                              The Cloisters   6228
# 15                   Robert Lehman Collection   5481
# 16                         European Paintings   3179
# 17                        Musical Instruments   2579
# 18                Modern and Contemporary Art   1456
# 19                              The Libraries    519

# %% [markdown]
# So if we use the top 5 classes of this, it could still be tons of data and work well.

# %% [markdown]
# Let's investigate what information is available about each object.

# %%
# %%bigquery tbl2
# SELECT * FROM `bigquery-public-data.the_met.objects` limit 50

# %%
tbl2.columns
# Out:
# Index(['object_number', 'is_highlight', 'is_public_domain', 'object_id',
#        'department', 'object_name', 'title', 'culture', 'period', 'dynasty',
#        'reign', 'portfolio', 'artist_role', 'artist_prefix',
#        'artist_display_name', 'artist_display_bio', 'artist_suffix',
#        'artist_alpha_sort', 'artist_nationality', 'artist_begin_date',
#        'artist_end_date', 'object_date', 'object_begin_date',
#        'object_end_date', 'medium', 'dimensions', 'credit_line',
#        'geography_type', 'city', 'state', 'county', 'country', 'region',
#        'subregion', 'locale', 'locus', 'excavation', 'river', 'classification',
#        'rights_and_reproduction', 'link_resource', 'metadata_date',
#        'repository'],
#       dtype='object')

# %% [markdown]
# Investigating date - it seems that there aren't a lot of them with set dates, so this isn't the best route.

# %%
# %%bigquery
# SELECT a.object_date, count(DISTINCT b.gcs_url)
# FROM `bigquery-public-data.the_met.objects` a JOIN `bigquery-public-data.the_met.images` b
# on a.object_id = b.object_id GROUP BY a.object_date ORDER BY 2 desc
# limit 30
# Out:
#                      object_date    f0_
# 0                           None  18418
# 1                   18th century  15409
# 2                   19th century  11639
# 3                   17th century   8755
# 4                   16th century   7706
# 5             early 19th century   3418
# 6              18th–19th century   3373
# 7                   15th century   3276
# 8                          1880s   2096
# 9              16th–17th century   1990
# 10                          n.d.   1946
# 11            ca. 1479–1458 B.C.   1941
# 12             late 18th century   1868
# 13                      ca. 1888   1858
# 14                  14th century   1788
# 15            early 18th century   1639
# 16                   1850s–1910s   1597
# 17             ca. 1150–ca. 1250   1517
# 18            early 17th century   1412
# 19             17th–18th century   1381
# 20                  13th century   1377
# 21                   7th century   1355
# 22             late 17th century   1320
# 23                         1860s   1302
# 24               4th–7th century   1280
# 25              9th–10th century   1276
# 26  late 18th–early 19th century   1235
# 27             15th–16th century   1226
# 28              mid-19th century   1217
# 29                       1860–70   1205

# %% [markdown]
# What about medium?

# %%
# %%bigquery
# SELECT a.medium, count(DISTINCT b.gcs_url)
# FROM `bigquery-public-data.the_met.objects` a JOIN `bigquery-public-data.the_met.images` b
# on a.object_id = b.object_id GROUP BY a.medium ORDER BY 2 desc limit 50
# Out:
#                                                medium   f0_
# 0                                              Bronze  8652
# 1                                              Silver  8354
# 2                                                Silk  7474
# 3                                          Terracotta  7030
# 4                                               Glass  6078
# 5                                             Woodcut  5573
# 6                                             Etching  5457
# 7                                                silk  5048
# 8                                                Gold  4723
# 9                                           Engraving  4301
# 10                               Hard-paste porcelain  3865
# 11                              Albumen silver prints  3628
# 12                                            Faience  3410
# 13           Albumen silver print from glass negative  3397
# 14                                               None  3329
# 15                                 Albumen photograph  3283
# 16     Woodblock printed book; ink and color on paper  3121
# 17                                      Oil on canvas  3089
# 18  Polychrome woodblock print; ink and color on p...  3074
# 19                                          Porcelain  2868
# 20                                              Ivory  2867
# 21                                        Bobbin lace  2777
# 22                                          Limestone  2775
# 23                        Commercial color lithograph  2590
# 24                               Soft-paste porcelain  2559
# 25                                            Ceramic  2522
# 26                                             cotton  2433
# 27                                             Marble  2377
# 28          Ink, opaque watercolor, and gold on paper  2245
# 29                  Wood; carved, painted, and gilded  2192
# 30                                               Wood  2173
# 31                                              Stone  2141
# 32                                       Copper alloy  1947
# 33                             Tin-glazed earthenware  1815
# 34                                             Cotton  1782
# 35                                              Steel  1723
# 36                                               Iron  1633
# 37                              Silk and metal thread  1544
# 38                                            Pottery  1527
# 39                                     Glass, ceramic  1513
# 40                              [no medium available]  1503
# 41                                        Earthenware  1478
# 42                                   Limestone, paint  1359
# 43           Wool, linen; plain weave, tapestry weave  1290
# 44                                              Linen  1273
# 45                                             Copper  1264
# 46                                       Ink on paper  1198
# 47  Set of three woodblock printed books; ink and ...  1191
# 48                              Silk / Compound weave  1172
# 49               Woodblock printed book; ink on paper  1170

# %% [markdown]
# Medium is surprisingly disappointing!  Ultimately, we settled on culture, which can be seen below.

# %%
# %%bigquery
# SELECT a.culture, count(DISTINCT b.gcs_url)
# FROM `bigquery-public-data.the_met.objects` a JOIN `bigquery-public-data.the_met.images` b
# on a.object_id = b.object_id GROUP BY a.culture ORDER BY 2 desc limit 50
# Out:
#                        culture     f0_
# 0                         None  155813
# 1                        Japan   43278
# 2                        China   23351
# 3                     American   21249
# 4                       French   20244
# 5                      Italian    9102
# 6                      British    8196
# 7                        Roman    5575
# 8                       German    5175
# 9                French, Paris    4025
# 10                      Coptic    3130
# 11                     Cypriot    2589
# 12                    Japanese    2589
# 13                     Spanish    2468
# 14             British, London    2431
# 15        American or European    2000
# 16                    European    1989
# 17                Greek, Attic    1922
# 18                   Byzantine    1732
# 19  European or Middle Eastern    1515
# 20                    Frankish    1425
# 21         South Netherlandish    1386
# 22             Italian, Venice    1368
# 23                       Greek    1344
# 24                    Etruscan    1304
# 25                       Dutch    1212
# 26             German, Meissen    1174
# 27                        Iran    1119
# 28              French, Sèvres    1016
# 29                      Minoan     981
# 30                     Flemish     957
# 31                     Chinese     933
# 32                    Sasanian     921
# 33                       Korea     887
# 34            Indonesia (Java)     856
# 35                     Mexican     837
# 36           Italian, Florence     775
# 37      British, Staffordshire     747
# 38            British, Chelsea     704
# 39            German, Augsburg     682
# 40                     Paracas     653
# 41           German, Nuremberg     588
# 42             Italian, Naples     571
# 43                    Austrian     568
# 44             probably French     566
# 45                       Moche     530
# 46                    Assyrian     529
# 47                     Russian     510
# 48            Austrian, Vienna     488
# 49               Italian, Rome     476

# %%
# %%bigquery
# SELECT a.culture, count(DISTINCT b.object_id)
# FROM `bigquery-public-data.the_met.objects` a JOIN `bigquery-public-data.the_met.images` b
# on a.object_id = b.object_id GROUP BY a.culture ORDER BY 2 desc limit 10
# Out:
#     culture    f0_
# 0      None  85443
# 1     Japan  14746
# 2     China  10429
# 3  American   9239
# 4    French   8853
# 5   Italian   4220
# 6     Roman   3563
# 7   British   3416
# 8    German   2108
# 9   Cypriot   1935

# %% [markdown]
# Now let's see how many images there are that we can access.

# %%
# %%bigquery
# SELECT count(DISTINCT b.gcs_url)
# FROM `bigquery-public-data.the_met.objects` a JOIN `bigquery-public-data.the_met.images` b
# on a.object_id = b.object_id
# LIMIT 16
# Out:
#       f0_
# 0  401477

# %%
# %%bigquery
# select count(*) from `bigquery-public-data.the_met.images`
# Out:
#       f0_
# 0  401596

# %% [markdown]
# Let's see what this looks like in a table.

# %%
# %%bigquery
# SELECT
#     *
# FROM `bigquery-public-data.the_met.images`
# --GROUP BY year
# --ORDER BY year DESC
# LIMIT 45
# Out:
#     object_id                                     public_caption title  \
# 0      435868          Fig. 8. X-radiograph of The Met, 61.101.1  None
# 1      634108  Fig. 5. Ferdinand Hodler, sketch for "The Drea...  None
# 2      634108  Fig. 2. Ferdinand Hodler, sketch for "The Drea...  None
# 3      634108  Fig. 7. Ferdinand Hodler, sketch for "The Drea...  None
# 4      634108  Fig. 6. Ferdinand Hodler, sketch for "The Drea...  None
# 5      634108  Fig. 3. Ferdinand Hodler, sketch for "The Drea...  None
# 6      634108  Fig. 4. Ferdinand Hodler, sketch for "The Drea...  None
# 7      435868  Fig. 1. Paul Cézanne, "The Card Players," ca. ...  None
# 8      435868  Fig. 7. Antoine Le Nain, "The Little Card Play...  None
# 9      435868  Fig. 3. Paul Cézanne, "The Card Players," ca. ...  None
# 10     437814       Fig. 1. Diagram identifying figures depicted  None
# 11     435868  Fig. 4.  Paul Cézanne, "Man with Pipe," 1892/1...  None
# 12     436050  Fig. 1. Giovanni di Bartolommeo Cristiani, "Sa...  None
# 13     437127  Fig. 8. "Corner of river-garden at Trocadéro" ...  None
# 14     436759  Fig. 1. Master of the Pomposa Chapterhouse (po...  None
# 15     436759  Fig. 2. Master of the Pomposa Chapterhouse (po...  None
# 16     436759  Fig. 3. Master of the Pomposa Chapterhouse (po...  None
# 17     436759  Fig. 4. Follower of Giotto, "Incredulity of Sa...  None
# 18     436759  Fig. 5. Follower of Giotto, "Ascension of Chri...  None
# 19     436759  Fig. 7. Follower of Giotto, "Madonna and Child...  None
# 20     436759  Fig. 6. Master of the Pomposa Chapterhouse, "T...  None
# 21     435868  Fig. 6. Mathieu Le Nain, "The Card Players (Le...  None
# 22     671456  Fig. 2. Gustave Caillebotte, Door Panels for t...  None
# 23     436050  Fig. 2. Giovanni di Bartolommeo Cristiani, "Th...  None
# 24     157941                        Portrait of Mina A. Clement  None
# 25     437638  Fig. 1. Andrea Schiavone, "The Marriage of Cup...  None
# 26     437638                      Fig. 2. Infrared reflectogram  None
# 27     438688  Fig. 1. Federico Barocci, "Christ Taking Leave...  None
# 28     438688  Fig. 2. Federico Barocci, studies for the figu...  None
# 29     438688  Fig. 3. Federico Barocci, study for the figure...  None
# 30     671456  Fig. 1. Martial Caillebotte, Gustave Caillebot...  None
# 31     437127  Fig. 2. Claude Monet, "Japanese Footbridge, Gi...  None
# 32     437127  Fig. 5. Untitled photograph (Durand-Ruel Archi...  None
# 33     436050  Fig. 3. Engraving after Cristiani, "The Funera...  None
# 34     436050                  Fig. 4. Altarpiece reconstruction  None
# 35     435868  Fig. 5. Paul Cézanne, "Man with a Pipe," 1892–...  None
# 36     435894  Fig. 1. Carlo Maratti, "Bathsheba at Her Bath,...  None
# 37     671456  Fig. 4. Claude Monet, "Bed of Chrysanthemums,"...  None
# 38     437127  Fig. 1. Lilla Cabot Perry, "Bridge in Giverny,...  None
# 39     437127  Fig. 4. Claude Monet, "Water-Lily Pond, Sympho...  None
# 40     436155  Fig. 1. Edgar Degas, Répétition d’un ballet su...  None
# 41     437127  Fig. 3. Claude Monet, "The Water-Lily Pond," 1...  None
# 42     437112  Fig. 2. Claude Monet, Jerusalem Artichoke Flow...  None
# 43     555676  Curatorial Interpretation Figure 2: Reconstruc...  None
# 44     555676  Curatorial Interpretation Figure 3: Reconstruc...  None
#
#                                    original_image_url caption  is_oasc  \
# 0   http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 1   http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 2   http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 3   http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 4   http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 5   http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 6   http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 7   http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 8   http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 9   http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 10  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 11  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 12  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 13  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 14  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 15  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 16  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 17  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 18  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 19  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 20  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 21  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 22  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 23  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 24  http://images.metmuseum.org/CRDImages/ci/origi...    None    False
# 25  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 26  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 27  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 28  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 29  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 30  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 31  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 32  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 33  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 34  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 35  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 36  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 37  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 38  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 39  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 40  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 41  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 42  http://images.metmuseum.org/CRDImages/ep/origi...    None    False
# 43  http://images.metmuseum.org/CRDImages/eg/origi...    None    False
# 44  http://images.metmuseum.org/CRDImages/eg/origi...    None    False
#
#                                    gcs_url
# 0   gs://gcs-public-data--met/435868/8.jpg
# 1   gs://gcs-public-data--met/634108/5.jpg
# 2   gs://gcs-public-data--met/634108/2.jpg
# 3   gs://gcs-public-data--met/634108/7.jpg
# 4   gs://gcs-public-data--met/634108/6.jpg
# 5   gs://gcs-public-data--met/634108/3.jpg
# 6   gs://gcs-public-data--met/634108/4.jpg
# 7   gs://gcs-public-data--met/435868/1.jpg
# 8   gs://gcs-public-data--met/435868/7.jpg
# 9   gs://gcs-public-data--met/435868/3.jpg
# 10  gs://gcs-public-data--met/437814/1.jpg
# 11  gs://gcs-public-data--met/435868/4.jpg
# 12  gs://gcs-public-data--met/436050/4.jpg
# 13  gs://gcs-public-data--met/437127/8.jpg
# 14  gs://gcs-public-data--met/436759/1.jpg
# 15  gs://gcs-public-data--met/436759/2.jpg
# 16  gs://gcs-public-data--met/436759/3.jpg
# 17  gs://gcs-public-data--met/436759/4.jpg
# 18  gs://gcs-public-data--met/436759/5.jpg
# 19  gs://gcs-public-data--met/436759/7.jpg
# 20  gs://gcs-public-data--met/436759/6.jpg
# 21  gs://gcs-public-data--met/435868/6.jpg
# 22  gs://gcs-public-data--met/671456/2.jpg
# 23  gs://gcs-public-data--met/436050/5.jpg
# 24  gs://gcs-public-data--met/157941/2.jpg
# 25  gs://gcs-public-data--met/437638/1.jpg
# 26  gs://gcs-public-data--met/437638/2.jpg
# 27  gs://gcs-public-data--met/438688/1.jpg
# 28  gs://gcs-public-data--met/438688/2.jpg
# 29  gs://gcs-public-data--met/438688/3.jpg
# 30  gs://gcs-public-data--met/671456/1.jpg
# 31  gs://gcs-public-data--met/437127/2.jpg
# 32  gs://gcs-public-data--met/437127/5.jpg
# 33  gs://gcs-public-data--met/436050/6.jpg
# 34  gs://gcs-public-data--met/436050/7.jpg
# 35  gs://gcs-public-data--met/435868/5.jpg
# 36  gs://gcs-public-data--met/435894/1.jpg
# 37  gs://gcs-public-data--met/671456/4.jpg
# 38  gs://gcs-public-data--met/437127/1.jpg
# 39  gs://gcs-public-data--met/437127/4.jpg
# 40  gs://gcs-public-data--met/436155/1.jpg
# 41  gs://gcs-public-data--met/437127/3.jpg
# 42  gs://gcs-public-data--met/437112/2.jpg
# 43  gs://gcs-public-data--met/555676/3.jpg
# 44  gs://gcs-public-data--met/555676/4.jpg

# %% [markdown]
# Pulling it into a pandas dataframe to work with:

# %%
# %%bigquery tbl1
# SELECT
#     *
# FROM `bigquery-public-data.the_met.images`
# --GROUP BY year
# ORDER BY object_id DESC
# LIMIT 15

# %%
tbl1
# Out:
#     object_id public_caption title  \
# 0      746939           None  None
# 1      746938           None  None
# 2      746760           None  None
# 3      746760           None  None
# 4      746760           None  None
# 5      746760           None  None
# 6      746760           None  None
# 7      746760           None  None
# 8      746760           None  None
# 9      746253           None  None
# 10     746252           None  None
# 11     746251           None  None
# 12     746251           None  None
# 13     746250           None  None
# 14     746250           None  None
#
#                                    original_image_url           caption  \
# 0   http://images.metmuseum.org/CRDImages/es/origi...              None
# 1   http://images.metmuseum.org/CRDImages/es/origi...              None
# 2   http://images.metmuseum.org/CRDImages/es/origi...              None
# 3   http://images.metmuseum.org/CRDImages/es/origi...              None
# 4   http://images.metmuseum.org/CRDImages/es/origi...              None
# 5   http://images.metmuseum.org/CRDImages/es/origi...              None
# 6   http://images.metmuseum.org/CRDImages/es/origi...              None
# 7   http://images.metmuseum.org/CRDImages/es/origi...              None
# 8   http://images.metmuseum.org/CRDImages/es/origi...              None
# 9   http://images.metmuseum.org/CRDImages/eg/origi...            view 1
# 10  http://images.metmuseum.org/CRDImages/eg/origi...            view 1
# 11  http://images.metmuseum.org/CRDImages/eg/origi...  proper R profile
# 12  http://images.metmuseum.org/CRDImages/eg/origi...              back
# 13  http://images.metmuseum.org/CRDImages/eg/origi...  proper R profile
# 14  http://images.metmuseum.org/CRDImages/eg/origi...              back
#
#     is_oasc                                 gcs_url
# 0      True  gs://gcs-public-data--met/746939/0.jpg
# 1      True  gs://gcs-public-data--met/746938/0.jpg
# 2      True  gs://gcs-public-data--met/746760/1.jpg
# 3      True  gs://gcs-public-data--met/746760/5.jpg
# 4      True  gs://gcs-public-data--met/746760/0.jpg
# 5      True  gs://gcs-public-data--met/746760/2.jpg
# 6      True  gs://gcs-public-data--met/746760/4.jpg
# 7      True  gs://gcs-public-data--met/746760/6.jpg
# 8      True  gs://gcs-public-data--met/746760/3.jpg
# 9      True  gs://gcs-public-data--met/746253/0.jpg
# 10     True  gs://gcs-public-data--met/746252/0.jpg
# 11     True  gs://gcs-public-data--met/746251/1.jpg
# 12     True  gs://gcs-public-data--met/746251/0.jpg
# 13     True  gs://gcs-public-data--met/746250/1.jpg
# 14     True  gs://gcs-public-data--met/746250/0.jpg

# %% [markdown]
# ## 3. Reviewing Download Speeds
#
# Now that I can find all of the locations of each item, it's worth understanding how fast they are to download, seeing how the data should be structured - Should it be put in a bucket or local VM, or can it be accessed from the public bucket?  Understanding latency will be important.

# %%
import urllib
import os
from google.cloud import storage

# %% [markdown]
# Setting up the bucket:

# %%
#load the bucketname
credential_path = r"C:\Users\matfl\Documents\MSCA 31009 Project - CREDENTIALS.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credential_path

storage_client = storage.Client()
bucket = storage_client.get_bucket('met-image-bucket')

# %% [markdown]
# Timing how long it takes to load the file using the python interface.

# %%
# %%timeit
#make this a file
#name variable
fn = tbl1.loc[0,'object_id'].astype(str)+'image.jpg'
urllib.request.urlretrieve(tbl1.loc[0, 'original_image_url'], fn)
#load the file onto gcp
blob = bucket.blob(fn)
blob.upload_from_filename(fn)
# Out:
# 2.06 s ± 182 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# This...does not scale to thousands of images.

# %% [markdown]
# So, I tried a few pieces in gsutil:
#
#
# <code>
# matflig@cloudshell:~ (msca-31009-project)$ gsutil cp gs://gcs-public-data--met/746760/3.jpg gs://met-image-bucket
# </code>
#
# This does it in gsutil! Let me try adding the -r flag, and the -m flag, which allow multithreading, and moving whole folders.
#
# <code>
# matflig@cloudshell:~ (msca-31009-project)$ gsutil -m cp -r gs://gcs-public-data--met/* gs://met-image-bucket/
# </code>
#
# Now, I'll need to move it to persistent disk, get it restructured into the train and test, then arrange by y variable, and then possibly take them out of folders.
#
# Size of data:
#
# <code>
# matflig@cloudshell:~ (msca-31009-project)$ gsutil du -sh gs://met-image-bucket/
# </code>
#
# ..Large. about 100 gb.

# %% [markdown]
# Now, to attempt writing a shell script.  (NOTE - some of this may overlap with the other script that assembles shell scripts, much of it built off of investigations here).
#
# Below, I test out writing a script that moves each of the individual items.

# %%
# %%bigquery todel_test
# SELECT object_id FROM `bigquery-public-data.the_met.objects` WHERE department='The Libraries'

# %%
script = '\n'.join(todel_test['object_id'].apply(lambda x: 'gsutil rm -r gs://met-image-bucket/'+str(x)).tolist())

# %%
script
# Out:
# 'gsutil rm -r gs://met-image-bucket/681274\ngsutil rm -r gs://met-image-bucket/681259\ngsutil rm -r gs://met-image-bucket/682011\ngsutil rm -r gs://met-image-bucket/591859\ngsutil rm -r gs://met-image-bucket/591857\ngsutil rm -r gs://met-image-bucket/591868\ngsutil rm -r gs://met-image-bucket/705638\ngsutil rm -r gs://met-image-bucket/591846\ngsutil rm -r gs://met-image-bucket/591833\ngsutil rm -r gs://met-image-bucket/591837\ngsutil rm -r gs://met-image-bucket/591850\ngsutil rm -r gs://met-image-bucket/734108\ngsutil rm -r gs://met-image-bucket/734109\ngsutil rm -r gs://met-image-bucket/734110\ngsutil rm -r gs://met-image-bucket/734111\ngsutil rm -r gs://met-image-bucket/738516\ngsutil rm -r gs://met-image-bucket/700238\ngsutil rm -r gs://met-image-bucket/591856\ngsutil rm -r gs://met-image-bucket/591861\ngsutil rm -r gs://met-image-bucket/738466\ngsutil rm -r gs://met-image-bucket/700032\ngsutil rm -r gs://met-image-bucket/700050\ngsutil rm -r gs://met-image-bucket/591862\ngsutil rm -r gs://met-image-bucket/738463\ngsutil rm -r gs://met-image-bucket/591835\ngsutil rm -r gs://met-image-bucket/591836\ngsutil rm -r gs://met-image-bucket/716648\ngsutil rm -r gs://met-image-bucket/726717\ngsutil rm -r gs://met-image-bucket/591844\ngsutil rm -r gs://met-image-bucket/591834\ngsutil rm -r gs://met-image-bucket/591849\ngsutil rm -r gs://met-image-bucket/591851\ngsutil rm -r gs://met-image-bucket/591854\ngsutil rm -r gs://met-image-bucket/705290\ngsutil rm -r gs://met-image-bucket/591845\ngsutil rm -r gs://met-image-bucket/591847\ngsutil rm -r gs://met-image-bucket/591852\ngsutil rm -r gs://met-image-bucket/591853\ngsutil rm -r gs://met-image-bucket/704714\ngsutil rm -r gs://met-image-bucket/591832\ngsutil rm -r gs://met-image-bucket/715005\ngsutil rm -r gs://met-image-bucket/700240\ngsutil rm -r gs://met-image-bucket/591839\ngsutil rm -r gs://met-image-bucket/591829\ngsutil rm -r gs://met-image-bucket/591826\ngsutil rm -r gs://met-image-bucket/591828\ngsutil rm -r gs://met-image-bucket/591830\ngsutil rm -r gs://met-image-bucket/591860\ngsutil rm -r gs://met-image-bucket/591855\ngsutil rm -r gs://met-image-bucket/591843\ngsutil rm -r gs://met-image-bucket/591824\ngsutil rm -r gs://met-image-bucket/726678\ngsutil rm -r gs://met-image-bucket/739504\ngsutil rm -r gs://met-image-bucket/591827\ngsutil rm -r gs://met-image-bucket/591825\ngsutil rm -r gs://met-image-bucket/726677\ngsutil rm -r gs://met-image-bucket/591840\ngsutil rm -r gs://met-image-bucket/707455\ngsutil rm -r gs://met-image-bucket/726673\ngsutil rm -r gs://met-image-bucket/716639\ngsutil rm -r gs://met-image-bucket/591831\ngsutil rm -r gs://met-image-bucket/591865\ngsutil rm -r gs://met-image-bucket/591841\ngsutil rm -r gs://met-image-bucket/726669\ngsutil rm -r gs://met-image-bucket/738758\ngsutil rm -r gs://met-image-bucket/699505\ngsutil rm -r gs://met-image-bucket/700232\ngsutil rm -r gs://met-image-bucket/591848\ngsutil rm -r gs://met-image-bucket/700091\ngsutil rm -r gs://met-image-bucket/697348\ngsutil rm -r gs://met-image-bucket/738765\ngsutil rm -r gs://met-image-bucket/681349\ngsutil rm -r gs://met-image-bucket/680819\ngsutil rm -r gs://met-image-bucket/678732\ngsutil rm -r gs://met-image-bucket/679638\ngsutil rm -r gs://met-image-bucket/681269\ngsutil rm -r gs://met-image-bucket/591838\ngsutil rm -r gs://met-image-bucket/680821\ngsutil rm -r gs://met-image-bucket/681246\ngsutil rm -r gs://met-image-bucket/682098\ngsutil rm -r gs://met-image-bucket/680318\ngsutil rm -r gs://met-image-bucket/681384\ngsutil rm -r gs://met-image-bucket/682015\ngsutil rm -r gs://met-image-bucket/681504\ngsutil rm -r gs://met-image-bucket/682010\ngsutil rm -r gs://met-image-bucket/681559\ngsutil rm -r gs://met-image-bucket/681386\ngsutil rm -r gs://met-image-bucket/679476\ngsutil rm -r gs://met-image-bucket/681357\ngsutil rm -r gs://met-image-bucket/681502\ngsutil rm -r gs://met-image-bucket/591842\ngsutil rm -r gs://met-image-bucket/591863\ngsutil rm -r gs://met-image-bucket/680708\n ...

# %% [markdown]
# ### 4. Defining What to Run in gsutil

# %% [markdown]
# Now, to make an actual shell script from the text.

# %%
f = open("demofile2.sh", "w")
f.write(script)
f.close()

#made a version called demofile without gsutil at the start

# %% [markdown]
# The above had to be changed and remade, like below.

# %%
scriptl = '\n'.join(todel_test['object_id'].apply(lambda x: 'gsutil -m cp -r gs://gcs-public-data--met/'+str(x)\
                                                  +'* gs://met-image-bucket/').tolist()).encode('utf8')
f = open("demofilel.sh", "wb")
f.write(scriptl)
f.close()

# %% [markdown]
# This is slow, so I am going to try putting everything that needs to be done on one line.  This eventually worked!

# %%
scriptfs = 'gsutil -m rm -r'+' '.join(todel_test['object_id'].apply(lambda x: ' gs://met-image-bucket/'+str(x)).tolist())
scriptfs = scriptfs.encode('utf8')

# %%
f = open("demofilefs.sh", "wb")
f.write(scriptfs)
f.close()

# %% [markdown]
# To that end, I decided to, use python to select the test and train and validation and categories, make their folders, and then copy in the relevant jpg objects.
#
# There's a way to do this:
#
# <code>
# cat filelist | gsutil -m cp -I gs://my-bucket
#
#
# cat filelist | gsutil -m cp -I gs://met-image-bucket/mftst
# </code>
#
# Apparently the list needs to be a one per line..

# %%
scriptcp = '\n'.join(todel_test['object_id'].apply(lambda x: 'gs://gcs-public-data--met/'+str(x)+'/*.jpg').tolist())
scriptcp = scriptcp.encode('utf8')

f = open("demofilecp.sh", "wb")
f.write(scriptcp)
f.close()

# %% [markdown]
# <code>gsutil cat gs://met-image-bucket/demofilecp.sh | gsutil -m cp -I gs://met-image-bucket/mftst</code>
#
# This works!  Or, well, it would if they didn't all have the same name.  We may need to copy all of the folders, and then delete the json items, or figure out how to rename each picture on the way in.
#
# I think I'll have to copy all of the folders, with the json items, with a slightly modified version (will need there to be no /*jpg at the end):
#
# <code>gsutil cat gs://met-image-bucket/demofilecp.sh | gsutil -m cp -r -I gs://met-image-bucket/mftst </code>
#
# this works:
# <code>
# matflig@cloudshell:~ (msca-31009-project)$ gsutil cat gs://met-image-bucket/demofilecp.sh | gsutil -m cp -r -I gs://met-image-bucket/mftst</code>
#
# from there, I can probably move these accordingly and rename them?  Let's see how slow this is, since it has to be done line by line...

# %%
#script to newly copy in each of these as folders
scriptcp = '\n'.join(todel_test['object_id'].apply(lambda x: 'gs://gcs-public-data--met/'+str(x)).tolist())
scriptcp = scriptcp.encode('utf8')

f = open("demofilecp.sh", "wb")
f.write(scriptcp)
f.close()

# %% [markdown]
# Below is another version of the script that tries to rename these, in addition to copying them into folders.

# %%
#script to try and rename
scriptrn = '\n'.join(rn['gcs_url'].apply(lambda x: 'gsutil mv gs://met-image-bucket/mftst/'+str(x)[26:]+\
                                         ' gs://met-image-bucket/mftst/'+str(x)[26:].replace('/', '_')).tolist())
scriptrn = scriptrn.encode('utf8')
#scriptrn

# %%
f = open("demofilern.sh", "wb")
f.write(scriptrn)
f.close()

# %% [markdown]
# This would be <code>gsutil cat gs://met-image-bucket/demofilern.sh | sh</code>
#
# Aaand it does work but it is far too slow.

# %% [markdown]
# From here on stackoverflow this is a possibility:
#
# <code>gsutil ls -r gs://test-lab-12345-67890/\*\*/test_result_* | awk -F"/" {'system("gsutil cp "$0" \~/localpath/"$6)'}<code>
#
# https://stackoverflow.com/questions/48956181/gsutil-rename-files-as-they-are-being-copied-from-different-directories

# %% [markdown]
# Now to try this to understand the timing.

# %%
from os import environ
from google.cloud import storage

credential_path = r"C:\Users\matfl\Documents\MSCA 31009 Project - CREDENTIAL.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credential_path

storage_client = storage.Client()
bucket = storage_client.get_bucket('met-image-bucket')



def rename_file(bucket, bucketFolder, fileName):
    """Rename file in GCP bucket."""
    blob = bucket.blob(bucketFolder + fileName)
    bucket.rename_blob(blob,
                       new_name=(bucketFolder+fileName.replace('/', '_')))

# %%
blob = bucket.blob('mftst/'+str(testlist[1]))

# %%
bucket.rename_blob(blob, new_name=('mftst/'+str(testlist[1]).replace('/','_')))
# Out:
# <Blob: met-image-bucket, mftst/700240_1.jpg, 1595053204932529>

# %%
# %time rename_file(bucket, 'mftst/',str(testlist[15]))
# Out:
# Wall time: 543 ms

# %% [markdown]
# This could...scale? slowly but almost acceptibly?

# %%
for i in testlist:
    rename_file(bucket, 'mftst/', str(i))

# %%
len(testlist)
# Out:
# 519

# %% [markdown]
# Informally timed, but this took about 3 min for the five hundred files I tested with (whatever the length of testlist is) for this to do.  Some back of the envelope math...

# %%
100000/519 * 3 / 60
# Out:
# 9.633911368015415

# %% [markdown]
# About 10 hours.  All in all, will be about a day to process which...we have the time to do I guess?
#
# Going forward, I did indeed use these scripts in the next notebook (which does overlap with this one somewhat).
